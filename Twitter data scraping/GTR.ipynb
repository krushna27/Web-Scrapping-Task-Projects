# %%
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from time import sleep
import pandas as pd
import csv
import re

# %%
# Path to ChromeDriver executable
PATH = r"C:\chromedriver-win64\chromedriver.exe"

# Create ChromeOptions instance
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)
driver.get("https://twitter.com/login")

# %%
from selenium.common.exceptions import NoSuchElementException
UserDescriptions = []
UserFollowers = []
UserFollowing = []
UserLocation = []
UserUrl = []

# %%
csv_file_path = 'twitter_links1.csv'  # Replace 'your_file.csv' with the actual path to your CSV file
with open(csv_file_path, 'r') as csv_file:
    reader = csv.reader(csv_file)
    links = [row[0] for row in reader]
    subject = []


for link in links:
    # Extract username using regular expression
    username = re.search(r'https://twitter.com/([^/]+)', link)
    
    if username:
        subject.append(username.group(1))
new1 = subject        
print(subject)
# Out:
# ['GTNUK1', 'whatsapp', 'aacb_CBPTrade', 'aacbdotcom', '@AAWindowPRODUCT', 'ABHomeInc', 'Abrepro', 'ACChristofiLtd', 'aeclothing1', 'AETechnologies1', 'AGInsuranceLLC']

# %%
sleep(3)
username_input = driver.find_element(By.XPATH, "//input[@name='text']")
username_input.send_keys("@Bankark55")
next_button = driver.find_element(By.XPATH, "//span[contains(text(),'Next')]")
next_button.click()

# %%
sleep(3)
password_input = driver.find_element(By.XPATH, "//input[@name='password']")
password_input.send_keys('KrsnaX@27')
log_in_button = driver.find_element(By.XPATH, "//span[contains(text(),'Log in')]")
log_in_button.click()

# %%
user_profiles = []

for username in new1:
    try:
        sleep(3)
        search_box = driver.find_element(By.XPATH, "//input[@data-testid='SearchBox_Search_Input']")
        search_box.send_keys(username)
        search_box.send_keys(Keys.ENTER)

        sleep(3)
        people = driver.find_element(By.XPATH, "//span[contains(text(),'People')]")
        people.click()

        sleep(4)
        profile = driver.find_element(By.XPATH, '//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[3]/section/div/div/div[1]/div/div/div/div/div[2]/div[1]/div[1]/div/div[1]/a/div/div[1]/span/span[1]')
        profile.click()

        UserDescriptions = driver.find_element(By.XPATH, "//div[@data-testid='UserDescription']").text
        UserLocation = driver.find_element(By.XPATH, "//span[@data-testid='UserLocation']").text
        UserUrl = driver.find_element(By.XPATH, "//a[@data-testid='UserUrl']").text
        UserFollowers = driver.find_element(By.XPATH, "//span[@class='css-1qaijid r-bcqeeo r-qvutc0 r-poiln3 r-1b43r93 r-1cwl3u0 r-b88u0q']").text
        UserFollowing = driver.find_element(By.XPATH, "//a[@href='/" + username + "/verified_followers']//span[@class='css-1qaijid r-bcqeeo r-qvutc0 r-poiln3 r-1b43r93 r-1cwl3u0 r-b88u0q']").text

        # Store the information in a dictionary
        user_data = {
            'Username': username,
            'UserDescription': UserDescriptions,
            'UserLocation': UserLocation,
            'UserFollowers': UserFollowers,
            'UserFollowing': UserFollowing,
            'UserUrl': UserUrl
        }

        # Append the dictionary to the list
        user_profiles.append(user_data)

    except Exception as e:
        print(f"An error occurred for user {username}: {e}")
# Out:
# An error occurred for user GTNUK1: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[
# 	(No symbol) [0x00007FF7108688C4]
# 	BaseThreadInitThunk [0x00007FFEBB13257D+29]
# 	RtlUserThreadStart [0x00007FFEBCB8AA58+40]

# %%
    # sleep(3)
    # profile = driver.find_element(By.XPATH, '//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[3]/section/div/div/div[1]/div/div/div/div/div[2]/div[1]/div[1]/div/div[1]/a/div/div[1]/span/span[1]')
    # profile.click()

# %%
# UserDescriptions= driver.find_element(By.XPATH,"//div[@data-testid='UserDescription']").text
# # UserDescriptions.append(UserDescriptions)
# UserLocation = driver.find_element(By.XPATH,"//span[@data-testid='UserLocation']").text
# UserLocation.append(UserLocation)
# UserUrl = driver.find_element(By.XPATH,"//a[@data-testid='UserUrl']").text
# UserUrl.append(UserUrl)
# UserFollowers = driver.find_element(By.XPATH,"//span[@class='css-1qaijid r-bcqeeo r-qvutc0 r-poiln3 r-1b43r93 r-1cwl3u0 r-b88u0q']").text
# UserFollowers.append(UserFollowers)
# UserFollowing = driver.find_element(By.XPATH,"//a[@href='/GTNUK1/verified_followers']//span[@class='css-1qaijid r-bcqeeo r-qvutc0 r-poiln3 r-1b43r93 r-1cwl3u0 r-b88u0q']").text
# UserFollowing.append(UserFollowing)

# %%
# UserLocation = driver.find_element(By.XPATH,"//span[@data-testid='UserLocation']").text
# # UserLocation.append(UserLocation)

# %%
# UserUrl = driver.find_element(By.XPATH,"//a[@data-testid='UserUrl']").text
# # UserUrl.append(UserUrl)

# %%
# UserFollowers = driver.find_element(By.XPATH,"//span[@class='css-1qaijid r-bcqeeo r-qvutc0 r-poiln3 r-1b43r93 r-1cwl3u0 r-b88u0q']").text
# # UserFollowers.append(UserFollowers)

# %%
# UserFollowing = driver.find_element(By.XPATH,"//a[@href='/GTNUK1/verified_followers']//span[@class='css-1qaijid r-bcqeeo r-qvutc0 r-poiln3 r-1b43r93 r-1cwl3u0 r-b88u0q']").text
# # UserFollowing.append(UserFollowing)

# %%
df = pd.DataFrame(user_profiles)
df

# user_profiles
# Out:
#          Username                                    UserDescription  \
# 0      aacbdotcom  A & A Freight | Warehousing | Customs Brokerag...
# 1       ABHomeInc  Industry leader in wholesale home decor, furni...
# 2         Abrepro  From large format black & white prints to the ...
# 3  ACChristofiLtd  A & C CHRISTOFI LTD is a fast growing professi...
# 4     aeclothing1                          Used Clothing Distributor
# 5  AGInsuranceLLC  A & G Insurance prides itself on being your lo...
#
#            UserLocation UserFollowers UserFollowing             UserUrl
# 0             Worldwide         3,987           665            aacb.com
# 1  Rancho Cucamonga, CA           181           364       abhomeinc.com
# 2       Bentonville, AR           125           133         abrepro.com
# 3                Cyprus           292            89          acccyp.com
# 4              Carteret             0            15      aeclothing.net
# 5           Connecticut           260            42  aginsuranceinc.com

# %%
df.to_csv("thisisfinal.csv",index=True)
